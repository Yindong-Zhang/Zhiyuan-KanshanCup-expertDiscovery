# %%
import os
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
dataDir = '../data/zhihu competition'

# %% [markdown]
# ## 问题信息探索

# %% [markdown]
# [问题ID  问题创建时间  问题标题的单字编码序列  问题标题的切词编码序列  问题描述的单字编码序列  问题描述的词编码序列  问题绑定的话题ID]

# %%
qs_columns = ['question_id', 'create_time', 'title_SW', 'title_W', 'describe_SW', 'describe_W', 'question_topics']

# %%
qs_df = pd.read_csv(os.path.join(dataDir, 'question_info_0926.txt'), sep= '\t', nrows = None, names = qs_columns )

# %%
qs_df.head()
# Out:
#    question_id create_time                                           title_SW  \
# 0  Q2234111670    D1018-H5  SW211,SW204,SW1715,SW69,SW2033,SW138,SW57,SW13...
# 1   Q760329790   D1745-H20  SW69,SW2033,SW138,SW2616,SW2668,SW36,SW2594,SW...
# 2   Q741313548   D2032-H21  SW153,SW662,SW1218,SW853,SW325,SW1056,SW467,SW...
# 3  Q3481466230   D2185-H15  SW22,SW179,SW57,SW451,SW594,SW118,SW882,SW655,...
# 4  Q3966197028   D2269-H17  SW1622,SW223,SW1218,SW853,SW390,SW220,SW753,SW...
#
#                               title_W  \
# 0                  W22414,W963,W10458
# 1  W12677,W16829,W15201,W6419,W101839
# 2             W700,W2781,W3280,W81215
# 3    W3312,W1823,W1505,W638,W166,W461
# 4                     W700,W895,W2253
#
#                                          describe_SW  \
# 0                                                 -1
# 1  SW146,SW982,SW401,SW297,SW17,SW2616,SW2668,SW3...
# 2  SW1956,SW3583,SW153,SW34,SW35,SW1016,SW586,SW5...
# 3  SW323,SW37,SW1,SW606,SW1227,SW29,SW22,SW179,SW...
# 4                                                 -1
#
#                                           describe_W  \
# 0                                                 -1
# 1  W1296,W2118,W12677,W16829,W15201,W6419,W101839...
# 2  W732,W24400,W48321,W39608,W20788,W219486,W1183...
# 3  W6642,W4214,W3312,W1505,W2205,W232,W294,W7177,...
# 4                                                 -1
#
#                 question_topics
# 0         T321,T730,T5784,T4389
# 1             T278,T12673,T4677
# 2                          T226
# 3                     T51,T4468
# 4  T54700,T81,T57,T17670,T43574

# %% [markdown]
# ### question id 检查

# %%
nquestions= qs_df['question_id'].nunique()

# %%
nquestions
# Out:
# 1829900

# %%
assert nquestions == len(qs_df)

# %% [markdown]
# ### 问题时间检查

# %%
qs_df['create_day'] = qs_df['create_time'].apply(lambda x: int(x.split('-')[0].lstrip('D')))

# %%
qs_df['create_hour'] = qs_df['create_time'].apply(lambda x: int(x.split('-')[1].lstrip('H')))

# %%
qs_df['create_day'].describe()
# Out:
# count    1.829900e+06
# mean     3.691946e+03
# std      4.155294e+02
# min      7.530000e+02
# 25%      3.801000e+03
# 50%      3.836000e+03
# 75%      3.858000e+03
# max      3.874000e+03
# Name: create_day, dtype: float64

# %%
qs_df['create_day'].max() - qs_df['create_day'].min()
# Out:
# 3121

# %% [markdown]
# #### 问题创建天数 横跨 10年？

# %%
qs_df['create_day'].hist(bins= 20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 从问题时间分布看，应该可以认为较早的问题id属于脏数据

# %% [markdown]
# ### 问题标题长度统计

# %%
qs_df['title_SW_length'] = qs_df['title_SW'].apply(lambda x: x.count(',') + 1)

# %%
qs_df['title_SW_length'].describe()
# Out:
# count    1.829900e+06
# mean     2.140425e+01
# std      1.026526e+01
# min      1.000000e+00
# 25%      1.400000e+01
# 50%      1.900000e+01
# 75%      2.600000e+01
# max      1.250000e+02
# Name: title_SW_length, dtype: float64

# %%
qs_df['title_SW_length'].hist(bins= 20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 问题标题长度分布

# %%
qs_df['title_W_length'] = qs_df['title_W'].apply(lambda x: x.count(',') + 1)

# %%
qs_df['title_W_length'].describe()
# Out:
# count    1.829900e+06
# mean     6.665204e+00
# std      3.528144e+00
# min      1.000000e+00
# 25%      4.000000e+00
# 50%      6.000000e+00
# 75%      8.000000e+00
# max      3.800000e+01
# Name: title_W_length, dtype: float64

# %%
qs_df['title_W_length'].hist(bins = 20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 问题描述长度统计

# %%
np.sum(qs_df['describe_SW'] == '-1')
# Out:
# 948533

# %%
describe_empty_ratio = np.sum(qs_df['describe_SW'] == '-1') / len(qs_df)

# %%
describe_empty_ratio
# Out:
# 0.5183523689819116

# %% [markdown]
# #### 50%的问题描述为空
# #### 问题的描述为空可以单独作为一类

# %%
qs_df['describe_SW_length']= qs_df['describe_SW'].apply(lambda x: x.count(','))

# %%
qs_df['describe_SW_length'].describe()
# Out:
# count    1.829900e+06
# mean     5.370407e+01
# std      1.409841e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      5.500000e+01
# max      3.012000e+03
# Name: describe_SW_length, dtype: float64

# %%
qs_df['describe_SW_length'].hist(bins = [i * 5 for i in range(1, 100)])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 问题描述长度分布

# %% [markdown]
# #### 问题描述最长约2000字，最短没有，方差很大，问题描述的细致程度应该会和邀请人的回答意愿相关

# %% [markdown]
# ### 问题话题分布

# %%
np.sum(qs_df['question_topics'] == '-1') / len(qs_df)
# Out:
# 0.002117055576807476

# %% [markdown]
# #### 问题话题缺失很少

# %%
qs_df['question_topics_length'] = qs_df['question_topics'].apply(lambda x: x.count(',') + 1)

# %%
qs_df['question_topics_length'].describe()
# Out:
# count    1.829900e+06
# mean     2.753261e+00
# std      1.286661e+00
# min      1.000000e+00
# 25%      2.000000e+00
# 50%      3.000000e+00
# 75%      4.000000e+00
# max      1.600000e+01
# Name: question_topics_length, dtype: float64

# %%
topic_set = set()
for topics in qs_df['question_topics']:
    topic_list = topics.split(',')
    topic_set = topic_set | set(topic_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-4bb4a2795270> in <module>
#       2 for topics in qs_df['question_topics']:
#       3     topic_list = topics.split(',')
# ----> 4     topic_set = topic_set | set(topic_list)
#
# KeyboardInterrupt:

# %%
len(topic_set)
# Out:
# 54616

# %% [markdown]
# #### 问题话题标签数，标签还是很多很多，50000个问题就有20000个标签
# #### 看来需要利用标签的语义信息

# %% [markdown]
# ## 邀请信息探索

# %%
invite_columns = ['question_id', 'user_id', 'create_time', 'isAnswer']

# %%
invite_df = pd.read_csv(os.path.join(dataDir, 'invite_info_0926.txt'), sep = '\t', names = invite_columns, nrows= None)

# %%
invite_df.head()
# Out:
#    question_id      user_id create_time  isAnswer
# 0  Q2166419046   M401693808   D3865-H22         0
# 1  Q1550017551  M3392373099   D3844-H11         0
# 2   Q604029601  M2317670257   D3862-H15         0
# 3  Q2350061229  M1618461867   D3849-H11         0
# 4  Q2443223942  M3544409350    D3867-H4         0

# %%
len(invite_df)
# Out:
# 9489162

# %% [markdown]
# #### 未清洗前1000万条邀请数据

# %%
nAnswer = np.sum(invite_df['isAnswer'] == 1)

# %%
nAnswer / len(invite_df)
# Out:
# 0.1773515933229931

# %% [markdown]
# #### 正负样本比例约为　1:4

# %% [markdown]
# ## 回答信息探索

# %% [markdown]
# [回答ID 问题ID 用户ID 回答创建时间 回答内容的单字编码序列 回答内容的切词编码序列 回答是否被标优 回答是否被推荐 回答是否被收入圆桌 是否包含图片 是否包含视频 回答字数 点赞数 取赞数 评论数 收藏数 感谢数 举报数 没有帮助数 反对数]

# %%
answer_columns = ['answer_id', 'question_id', 'user_id', 'create_time', 'answer_SW', 'answer_W',
                 'is_good', 'is_recommend', 'is_include', 'has_picture', 'has_video', 'word_count', 'num_zan',
                 'num_comment', 'num_collect', 'num_thanks', 'num_report', 'num_useless', 'num_oppose']

# %%
answer_df = pd.read_csv(os.path.join(dataDir, 'answer_info_0926.txt'), sep = '\t', names = answer_columns, nrows = None, index_col = False)

# %%
answer_df.head()
# Out:
#      answer_id  question_id      user_id create_time  \
# 0  A2502060945  Q1867533817   M625498202    D3808-H7
# 1  A2847829478  Q3366788616   M142330444   D3810-H17
# 2  A2005999231  Q4264694221   M771499642   D3853-H13
# 3    A14821523  Q1088851650  M2282072267   D3859-H18
# 4   A731550034  Q1023877868  M2282072267   D3855-H22
#
#                                            answer_SW  \
# 0  SW13,SW19,SW44,SW150,SW23,SW594,SW1254,SW91,SW...
# 1  SW898,SW3656,SW2,SW413,SW601,SW2,SW2541,SW681,...
# 2  SW9,SW510,SW573,SW1348,SW1304,SW326,SW509,SW22...
# 3  SW7,SW16,SW5,SW144,SW302,SW20,SW1752,SW60,SW75...
# 4  SW7,SW15,SW596,SW407,SW1698,SW68,SW2,SW56,SW59...
#
#                                             answer_W  is_good  is_recommend  \
# 0  W239,W10528,W142,W20372,W6473,W10,W24,W4527,W2...        0             0
# 1  W4628,W66060,W1607,W2647,W53385,W109029,W319,W...        0             0
# 2  W3532,W69108,W12395,W81311,W498,W850,W107789,W...        0             0
# 3  W1425,W1676,W3700,W325,W6485,W1090,W8342,W9689...        0             0
# 4  W23420,W2610,W5506,W1489,W8749,W504,W1718,W252...        0             0
#
#    is_include  has_picture  has_video  word_count  num_zan  num_comment  \
# 0           0            0          0          41        1            0
# 1           0            0          0         204        1            0
# 2           0            0          0          54        2            0
# 3           0            0          0          42        1            0
# 4           0            0          0          44        0            0
#
#    num_collect  num_thanks  num_report  num_useless  num_oppose
# 0            1           0           1            0           0
# 1            0           3           1            0           0
# 2            1           0           0            0           0
# 3            1           0           1            0           0
# 4            0           0           0            0           0

# %%
answer_df.describe()
# Out:
#             is_good  is_recommend  is_include   has_picture     has_video  \
# count  4.513735e+06  4.513735e+06   4513735.0  4.513735e+06  4.513735e+06
# mean   9.949632e-04  2.525625e-05         0.0  1.007053e-01  5.820235e-03
# std    3.152734e-02  5.025496e-03         0.0  3.009381e-01  7.606814e-02
# min    0.000000e+00  0.000000e+00         0.0  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00         0.0  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00         0.0  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00         0.0  0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00         0.0  1.000000e+00  1.000000e+00
#
#          word_count       num_zan   num_comment   num_collect    num_thanks  \
# count  4.513735e+06  4.513735e+06  4.513735e+06  4.513735e+06  4.513735e+06
# mean   1.709864e+02  8.193956e+00  4.386773e-01  1.882178e+00  3.186981e+00
# std    5.253362e+02  2.447460e+02  8.238401e+00  2.748486e+01  2.416192e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.300000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    5.500000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    1.480000e+02  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.210620e+05  8.659400e+04  4.829000e+03  1.914300e+04  1.359590e+05
#
#          num_report   num_useless    num_oppose
# count  4.513735e+06  4.513735e+06  4.513735e+06
# mean   1.088641e+00  1.899447e-02  1.861673e-02
# std    5.636396e+01  4.273088e-01  1.094725e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00
# max    4.343100e+04  2.550000e+02  2.065000e+03

# %% [markdown]
# #### is_include　都为 0，无用特征

# %%
answer_df['is_good'].value_counts()
# Out:
# 0    4509244
# 1       4491
# Name: is_good, dtype: int64

# %%
answer_df['has_video'].value_counts()
# Out:
# 0    4487464
# 1      26271
# Name: has_video, dtype: int64

# %%
answer_df['word_count'].hist(bins= [i * 10 for i in range(200)])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 回答字数分布

# %%
answer_df['num_zan'].hist(bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 点赞数分布，极其不均衡，可能服从指数分布

# %%
plt.hist(answer_df['num_zan'], bins = [0.2 * i for i in range(100)])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([3282286.,       0.,       0.,       0.,       0.,  561500.,
#               0.,       0.,       0.,       0.,  194017.,       0.,
#               0.,       0.,       0.,  102042.,       0.,       0.,
#               0.,       0.,   63239.,       0.,       0.,       0.,
#               0.,   43874.,       0.,       0.,       0.,       0.,
#           31042.,       0.,       0.,       0.,       0.,   24025.,
#               0.,       0.,       0.,       0.,   19581.,       0.,
#               0.,       0.,       0.,   15553.,       0.,       0.,
#               0.,       0.,   13093.,       0.,       0.,       0.,
#               0.,   10773.,       0.,       0.,       0.,       0.,
#            9202.,       0.,       0.,       0.,       0.,    8139.,
#               0.,       0.,       0.,       0.,    7151.,       0.,
#               0.,       0.,       0.,    6125.,       0.,       0.,
#               0.,       0.,    5545.,       0.,       0.,       0.,
#               0.,    4941.,       0.,       0.,       0.,       0.,
#            4423.,       0.,       0.,       0.,       0.,    3999.,
#               0.,       0.,       0.]),
#  array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#          2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#          4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#          6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#          8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. , 10.2, 10.4, 10.6, 10.8,
#         11. , 11.2, 11.4, 11.6, 11.8, 12. , 12.2, 12.4, 12.6, 12.8, 13. ,
#         13.2, 13.4, 13.6, 13.8, 14. , 14.2, 14.4, 14.6, 14.8, 15. , 15.2,
#         15.4, 15.6, 15.8, 16. , 16.2, 16.4, 16.6, 16.8, 17. , 17.2, 17.4,
#         17.6, 17.8, 18. , 18.2, 18.4, 18.6, 18.8, 19. , 19.2, 19.4, 19.6,
#         19.8]),
#  <a list of 99 Patch objects>)

# %% [markdown]
# #### 许多回答特征分布都是非常不均衡，绝大部分值是０，可能需要进行聚类，或者分箱转化为类别特征

# %% [markdown]
# ## 用户画像探索

# %% [markdown]
# 1.用户ID, 格式为 Mxxx。
#
#
#
# 2.性别。
#
#
#
# 3.创作关键词的编码序列，格式为 W1,W2,W3,...,Wn , 表示创作关键词的编码序号，如果创作关键词为空，则用 -1 进行占位。
#
#
#
# 4.创作数量等级。
#
#
#
# 5.创作热度等级。
#
#
#
# 6.注册类型。
#
#
#
# 7.注册平台。
#
#
#
# 8.访问频率，有五种取值 [new | daily | weekly | monthly | unknow] , 分别对应为 [新用户 | 日活用户 | 周活用户 | 月活用户 | 未知]。
#
#
#
# 9.用户二分类特征A，两种取值 0 或 1。
#
#
#
# 10.用户二分类特征B，两种取值 0 或 1。
#
#
#
# 11.用户二分类特征C，两种取值 0 或 1。
#
#
#
# 12.用户二分类特征D， 两种取值 0 或 1。
#
#
#
# 13.用户二分类特征E， 两种取值 0 或 1。
#
#
#
# 14.用户分类特征A, 格式为 MDxxx。
#
#
#
# 15.用户分类特征B, 格式为 BRxxx。
#
#
#
# 16.用户分类特征C, 格式为 PVxxx。
#
#
#
# 17.用户分类特征D, 格式为 CTxxx。
#
#
#
# 18.用户分类特征E, 格式为 PFxxx 。
#
#
#
# 19.用户的盐值分数。
#
#
#
# 20.用户关注的话题，格式为 T1,T2,T3,...,Tn , 表示用户关注话题的序列编号 (最多 100 个)，如果关注话题为空，则用 -1 进行占位。
#
#
#
# 21.用户感兴趣的话题，格式为 T1:0.2,T2:0.5:T3,-0.3,...,Tn:0.42 , 表示用户感兴趣的话题序列编号及喜好程度分数 (最多 10 个)，如果感兴趣话题为空，则用 -1 进行占位。

# %%
user_columns = ['user_id', 'gender', 'keywords', 'creation_num_level', 'creation_heat_level', 'register_type', 'register_platform',
               'visit_freq', 'binary_A', 'binary_B', 'binary_C', 'binary_D', 'binary_E', 'category_A', 'category_B', 'category_C', 
               'category_D', 'category_E', 'salt_value', 'follow_topics', 'interest_topics']

# %%
user_df = pd.read_csv(os.path.join(dataDir, 'member_info_0926.txt'), sep = '\t', names = user_columns, nrows = None)

# %%
user_df.head()
# Out:
#        user_id  gender  keywords  creation_num_level  creation_heat_level  \
# 0  M1934753188    male        -1                 0.0                  0.0
# 1   M595924114    male        -1                 0.0                  0.0
# 2  M1473482940  female        -1                 0.0                  0.0
# 3   M578477092    male        -1                 0.0                  0.0
# 4  M1088794709    male        -1                 0.0                  0.0
#
#   register_type register_platform visit_freq  binary_A  binary_B  ...  \
# 0       unknown           unknown    monthly         0         1  ...
# 1       unknown           unknown      daily         0         0  ...
# 2       unknown           unknown     weekly         0         1  ...
# 3       unknown           unknown      daily         1         1  ...
# 4       unknown           unknown     weekly         0         1  ...
#
#    binary_D  binary_E  category_A category_B category_C category_D category_E  \
# 0         1         0    MD470265   BR470265   PV929066   CT929066   PF470265
# 1         1         1    MD195122   BR596936   PV002320   CT840234   PF470265
# 2         1         0    MD116493   BR641329   PV170953   CT470265   PF470265
# 3         1         0    MD889589   BR803759   PV545833   CT545833   PF470265
# 4         0         0    MD825760   BR641329   PV071037   CT470265   PF470265
#
#   salt_value                                      follow_topics  \
# 0        764                                               T540
# 1        671  T44126,T15940,T839,T8978,T2934,T1113,T3914,T12...
# 2        454  T30874,T2113,T8656,T21,T523,T8,T116,T5727,T68,...
# 3        588  T946,T7323,T297,T2660,T36067,T53107,T2654,T507...
# 4        361  T582,T558,T28776,T5186,T9081,T2419,T2693,T2299...
#
#                                      interest_topics
# 0  T21107:1.7915097,T405:1.6123838,T4436:1.518003...
# 1  T18016:2.0650618,T2384:1.2503042,T1142:1.13569...
# 2  T46:1.330939,T2159:1.1296458,T379:1.1241927,T1...
# 3  T15918:1.9479566,T8106:1.8578106,T4787:1.58486...
# 4  T65:1.5992582,T867:1.3179373,T93:1.2095009,T31...
#
# [5 rows x 21 columns]

# %%
user_df.describe()
# Out:
#         keywords  creation_num_level  creation_heat_level      binary_A  \
# count  1931654.0           1931654.0            1931654.0  1.931654e+06
# mean        -1.0                 0.0                  0.0  5.973637e-01
# std          0.0                 0.0                  0.0  4.904288e-01
# min         -1.0                 0.0                  0.0  0.000000e+00
# 25%         -1.0                 0.0                  0.0  0.000000e+00
# 50%         -1.0                 0.0                  0.0  1.000000e+00
# 75%         -1.0                 0.0                  0.0  1.000000e+00
# max         -1.0                 0.0                  0.0  1.000000e+00
#
#            binary_B      binary_C      binary_D      binary_E    salt_value
# count  1.931654e+06  1.931654e+06  1.931654e+06  1.931654e+06  1.931654e+06
# mean   3.117147e-01  2.953117e-02  1.475352e-01  5.420381e-02  3.466341e+02
# std    4.631941e-01  1.692900e-01  3.546388e-01  2.264195e-01  8.260136e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  9.500000e+01
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  2.950000e+02
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  3.200000e+02
# 75%    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  3.730000e+02
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  8.900000e+02

# %% [markdown]
# #### 貌似绝大部分用户创作总数，和创作热度特征都是空的，绝大部分用户都是不活跃用户，很少回答问题

# %% [markdown]
# #### 事实上所有用户创作数和创作热度特征都是空的，这两个特征是无用特征

# %% [markdown]
# #### 用户性别：

# %%
user_df['gender'].nunique()
# Out:
# 3

# %%
user_df['gender'].unique()
# Out:
# array(['male', 'female', 'unknown'], dtype=object)

# %%
user_df['gender'].value_counts()
# Out:
# unknown    1227058
# female      413217
# male        291379
# Name: gender, dtype: int64

# %% [markdown]
# #### 性别中未知还是多数，未知作为单独一类

# %%
user_df['register_type'].unique()
# Out:
# array(['unknown'], dtype=object)

# %% [markdown]
# #### 所有用户的注册类型都是未知，无用特征

# %%
user_df['register_platform'].unique()
# Out:
# array(['unknown'], dtype=object)

# %% [markdown]
# #### 所有用户的注册平台都是未知，无用特征

# %% [markdown]
# #### 类别特征检查

# %%
for attr in ['A', 'B', 'C', 'D', 'E']:
    print(user_df['binary_%s' %(attr, )].nunique() == 2)
# Out:
# True
# True
# True
# True
# True

# %%
user_df['category_A'].nunique()
# Out:
# 2561

# %%
category_A_counts= user_df['category_A'].value_counts()
category_A_counts
# Out:
# MD470265    986602
# MD596647     63256
# MD116493     62180
# MD566292     58458
# MD661088     46717
# MD149461     40975
# MD634010     34365
# MD587649     33197
# MD825760     24006
# MD145384     20579
# MD590290     19746
# MD241358     15809
# MD401602     13248
# MD009370     11153
# MD026159     10302
# MD444325     10126
# MD705305      8992
# MD777214      8916
# MD886189      8415
# MD180416      8319
# MD353013      8303
# MD079507      8033
# MD872011      7991
# MD823600      7669
# MD782190      7474
# MD209763      7374
# MD281170      7357
# MD604656      7336
# MD637293      7241
# MD577600      6682
#              ...
# MD528040         1
# MD241970         1
# MD556886         1
# MD815028         1
# MD891982         1
# MD761190         1
# MD736905         1
# MD680941         1
# MD130271         1
# MD469798         1
# MD634488         1
# MD285599         1
# MD453826         1
# MD930331         1
# MD814172         1
# MD393871         1
# MD735165         1
# MD822975         1
# MD297739         1
# MD226046         1
# MD637030         1
# MD344004         1
# MD388883         1
# MD865278         1
# MD708592         1
# MD716692         1
# MD257166         1
# MD842815         1
# MD888076         1
# MD104593         1
# Name: category_A, Length: 2561, dtype: int64

# %%
category_A_counts.describe()
# Out:
# count      2561.000000
# mean        754.257712
# std       19697.441371
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%          29.000000
# max      986602.000000
# Name: category_A, dtype: float64

# %% [markdown]
# #### category_A 类别太多了，怎么处理？？
# #### 丢掉覆盖率比较低的特征？

# %%
category_A_counts / len(user_df) * 100
# Out:
# MD470265    51.075503
# MD596647     3.274707
# MD116493     3.219003
# MD566292     3.026318
# MD661088     2.418497
# MD149461     2.121239
# MD634010     1.779045
# MD587649     1.718579
# MD825760     1.242769
# MD145384     1.065356
# MD590290     1.022233
# MD241358     0.818418
# MD401602     0.685837
# MD009370     0.577381
# MD026159     0.533325
# MD444325     0.524214
# MD705305     0.465508
# MD777214     0.461573
# MD886189     0.435637
# MD180416     0.430667
# MD353013     0.429839
# MD079507     0.415861
# MD872011     0.413687
# MD823600     0.397017
# MD782190     0.386922
# MD209763     0.381745
# MD281170     0.380865
# MD604656     0.379778
# MD637293     0.374860
# MD577600     0.345921
#               ...
# MD528040     0.000052
# MD241970     0.000052
# MD556886     0.000052
# MD815028     0.000052
# MD891982     0.000052
# MD761190     0.000052
# MD736905     0.000052
# MD680941     0.000052
# MD130271     0.000052
# MD469798     0.000052
# MD634488     0.000052
# MD285599     0.000052
# MD453826     0.000052
# MD930331     0.000052
# MD814172     0.000052
# MD393871     0.000052
# MD735165     0.000052
# MD822975     0.000052
# MD297739     0.000052
# MD226046     0.000052
# MD637030     0.000052
# MD344004     0.000052
# MD388883     0.000052
# MD865278     0.000052
# MD708592     0.000052
# MD716692     0.000052
# MD257166     0.000052
# MD842815     0.000052
# MD888076     0.000052
# MD104593     0.000052
# Name: category_A, Length: 2561, dtype: float64

# %% [markdown]
# #### 各类别占总数的比例
# #### 可以将一部分类别合并
# #### 或者依据类别特征进行聚类

# %%
user_df['category_B'].nunique()
# Out:
# 291

# %%
user_df['category_B'].value_counts().describe()
# Out:
# count       291.000000
# mean       6637.986254
# std       63507.878293
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           7.000000
# max      986608.000000
# Name: category_B, dtype: float64

# %%
user_df['category_B'].value_counts() / len(user_df) * 100
# Out:
# BR470265    51.075814
# BR641329    21.200691
# BR803759     6.352173
# BR800099     4.718806
# BR896654     3.975453
# BR633087     3.864823
# BR214617     3.702371
# BR788740     1.389638
# BR412970     0.852171
# BR731759     0.688167
# BR129798     0.596950
# BR126824     0.349597
# BR871120     0.322470
# BR645390     0.181451
# BR504922     0.116325
# BR882923     0.061243
# BR957003     0.059897
# BR400878     0.050268
# BR390158     0.047317
# BR500021     0.047162
# BR915887     0.037533
# BR132406     0.026868
# BR029660     0.024383
# BR741959     0.023814
# BR707703     0.019413
# BR849661     0.018533
# BR411364     0.018482
# BR587648     0.016411
# BR100417     0.013615
# BR252694     0.011596
#               ...
# BR657807     0.000052
# BR374449     0.000052
# BR493149     0.000052
# BR087274     0.000052
# BR261228     0.000052
# BR577726     0.000052
# BR295780     0.000052
# BR356182     0.000052
# BR640879     0.000052
# BR708876     0.000052
# BR598674     0.000052
# BR454195     0.000052
# BR790067     0.000052
# BR140199     0.000052
# BR110355     0.000052
# BR265385     0.000052
# BR115979     0.000052
# BR628269     0.000052
# BR366277     0.000052
# BR687667     0.000052
# BR953404     0.000052
# BR886944     0.000052
# BR340966     0.000052
# BR203610     0.000052
# BR127897     0.000052
# BR436953     0.000052
# BR402631     0.000052
# BR158190     0.000052
# BR461419     0.000052
# BR708796     0.000052
# Name: category_B, Length: 291, dtype: float64

# %% [markdown]
# #### 可以做类别合并或者丢弃处理

# %%
user_df['category_C'].nunique()
# Out:
# 428

# %%
user_df['category_C'].value_counts().describe()
# Out:
# count       428.000000
# mean       4513.210280
# std       19857.452184
# min           1.000000
# 25%           3.000000
# 50%          14.000000
# 75%          85.250000
# max      218915.000000
# Name: category_C, dtype: float64

# %%
user_df['category_C'].value_counts() / len(user_df) * 100
# Out:
# PV008215    11.333034
# PV921755     6.982876
# PV625797     6.393743
# PV596305     5.908563
# PV545833     5.907166
# PV462839     4.996443
# PV002320     4.960930
# PV929066     4.691575
# PV426364     4.518459
# PV789063     3.651482
# PV071037     3.309910
# PV419710     3.191099
# PV421141     2.923505
# PV416399     2.889389
# PV280311     2.467574
# PV587951     2.410939
# PV736110     2.279445
# PV285968     2.263345
# PV923838     1.987778
# PV463198     1.883930
# PV394784     1.610589
# PV717084     1.459682
# PV725230     1.437110
# PV987623     1.227445
# PV649946     1.098903
# PV261182     0.976055
# PV833681     0.892448
# PV470265     0.879195
# PV713103     0.836485
# PV186293     0.509253
#               ...
# PV765568     0.000052
# PV904296     0.000052
# PV929130     0.000052
# PV944114     0.000052
# PV211774     0.000052
# PV562288     0.000052
# PV199562     0.000052
# PV383618     0.000052
# PV357068     0.000052
# PV577515     0.000052
# PV257832     0.000052
# PV904341     0.000052
# PV059246     0.000052
# PV395529     0.000052
# PV416618     0.000052
# PV256858     0.000052
# PV237749     0.000052
# PV308981     0.000052
# PV747304     0.000052
# PV193620     0.000052
# PV831723     0.000052
# PV804068     0.000052
# PV250492     0.000052
# PV150602     0.000052
# PV209345     0.000052
# PV307296     0.000052
# PV576930     0.000052
# PV320418     0.000052
# PV946856     0.000052
# PV989126     0.000052
# Name: category_C, Length: 428, dtype: float64

# %%
user_df['category_D'].nunique()
# Out:
# 1556

# %%
user_df['category_D'].value_counts()
# Out:
# CT470265    778428
# CT545833    114106
# CT929066     90625
# CT879618     51510
# CT721644     46986
# CT587951     46571
# CT569560     35659
# CT327012     33405
# CT513159     31280
# CT394784     31111
# CT378940     30244
# CT750817     24671
# CT300532     17918
# CT965658     15984
# CT022556     15369
# CT188616     14137
# CT322253     13271
# CT718720     13142
# CT537559     12871
# CT778120     11455
# CT396785     11401
# CT285502      9074
# CT761051      8781
# CT910844      7531
# CT704703      7490
# CT938734      7069
# CT014108      7052
# CT333114      6987
# CT397703      6931
# CT926763      6831
#              ...
# CT341220         1
# CT680179         1
# CT636928         1
# CT881417         1
# CT047269         1
# CT780607         1
# CT650738         1
# CT780457         1
# CT093026         1
# CT282630         1
# CT023909         1
# CT600734         1
# CT853250         1
# CT915603         1
# CT786866         1
# CT508748         1
# CT958083         1
# CT797267         1
# CT342167         1
# CT400816         1
# CT027921         1
# CT268865         1
# CT801614         1
# CT092823         1
# CT284849         1
# CT025898         1
# CT363385         1
# CT638882         1
# CT472525         1
# CT579772         1
# Name: category_D, Length: 1556, dtype: int64

# %%
user_df['category_D'].value_counts() / len(user_df) * 100
# Out:
# CT470265    40.298521
# CT545833     5.907166
# CT929066     4.691575
# CT879618     2.666627
# CT721644     2.432423
# CT587951     2.410939
# CT569560     1.846035
# CT327012     1.729347
# CT513159     1.619338
# CT394784     1.610589
# CT378940     1.565705
# CT750817     1.277196
# CT300532     0.927599
# CT965658     0.827477
# CT022556     0.795639
# CT188616     0.731860
# CT322253     0.687028
# CT718720     0.680350
# CT537559     0.666320
# CT778120     0.593015
# CT396785     0.590220
# CT285502     0.469753
# CT761051     0.454585
# CT910844     0.389873
# CT704703     0.387751
# CT938734     0.365956
# CT014108     0.365076
# CT333114     0.361711
# CT397703     0.358812
# CT926763     0.353635
#               ...
# CT341220     0.000052
# CT680179     0.000052
# CT636928     0.000052
# CT881417     0.000052
# CT047269     0.000052
# CT780607     0.000052
# CT650738     0.000052
# CT780457     0.000052
# CT093026     0.000052
# CT282630     0.000052
# CT023909     0.000052
# CT600734     0.000052
# CT853250     0.000052
# CT915603     0.000052
# CT786866     0.000052
# CT508748     0.000052
# CT958083     0.000052
# CT797267     0.000052
# CT342167     0.000052
# CT400816     0.000052
# CT027921     0.000052
# CT268865     0.000052
# CT801614     0.000052
# CT092823     0.000052
# CT284849     0.000052
# CT025898     0.000052
# CT363385     0.000052
# CT638882     0.000052
# CT472525     0.000052
# CT579772     0.000052
# Name: category_D, Length: 1556, dtype: float64

# %%
user_df['category_E'].nunique()
# Out:
# 2

# %%
user_df['category_E'].value_counts()
# Out:
# PF470265    1767878
# PF072986     163776
# Name: category_E, dtype: int64

# %% [markdown]
# #### 以上是用户属性 多值类别属性 类别数统计，有些类别数还是挺多的

# %%
user_df['follow_topics_count'] = user_df['follow_topics'].apply(lambda x: x.count(',') + 1)

# %%
user_df['follow_topics_count'].describe()
# Out:
# count    1.931654e+06
# mean     1.537387e+01
# std      2.107252e+01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      7.000000e+00
# 75%      2.000000e+01
# max      1.000000e+02
# Name: follow_topics_count, dtype: float64

# %%
np.sum(user_df['follow_topics'] == '-1')/len(user_df) * 100
# Out:
# 23.644710698706913

# %% [markdown]
# #### 关注话题最少１个，最多１００个

# %% [markdown]
# #### 百分之 22 的用户关注话题为空，考虑用均值填充 或者单独作为一类

# %%
np.sum(user_df['interest_topics'] == '-1')/len(user_df) * 100
# Out:
# 26.995155447093527

# %% [markdown]
# #### 26% 用户感兴趣话题为空，同样考虑用均值填充

# %%
user_df['interest_topics_count'] = user_df['interest_topics'].apply(lambda x: x.count(',') + 1)

# %%
user_df['interest_topics_count'].describe()
# Out:
# count    1.931654e+06
# mean     6.479220e+00
# std      4.155050e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+01
# 75%      1.000000e+01
# max      1.000000e+01
# Name: interest_topics_count, dtype: float64

# %% [markdown]
# #### 感兴趣话题最少一个，最多10个

# %%
user_df['interest_topics_count'].unique()
# Out:
# array([10,  1,  3,  4,  5,  2,  6,  7,  8,  9])

# %% [markdown]
# #### 访问频率特征无缺失

# %%
user_df['visit_freq'].unique()
# Out:
# array(['monthly', 'daily', 'weekly', 'unknown', 'new'], dtype=object)

# %% [markdown]
# #### 创作关键词特征

# %%
user_df['keywords'].head()
# Out:
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   -1
# Name: keywords, dtype: int64

# %%
np.sum(user_df['keywords'] == -1) / len(user_df) * 100
# Out:
# 100.0

# %% [markdown]
# #### 创作关键词都是空的，无用特征
